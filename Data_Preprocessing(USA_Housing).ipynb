# %%
# Importing all important Libraries

import pandas as pd

import numpy as np

import seaborn as sns

import matplotlib as plt

import warnings

warnings.filterwarnings('ignore')

from IPython import display

pd.set_option('display.max_columns',None)

pd.set_option('display.max_rows',None)

# %% [markdown]
# ## Data Preprocessing :

# %%
df = pd.read_csv('USA_Housing (2).csv')
df.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %% [markdown]
# ## Data Preprocessing :

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
df.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %%
df.nunique()
# Out:
# Avg. Area Income                5000
# Avg. Area House Age             5000
# Avg. Area Number of Rooms       5000
# Avg. Area Number of Bedrooms     255
# Area Population                 5000
# Price                           5000
# Address                         5000
# dtype: int64

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=5000, step=1),
#  Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#         'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#        dtype='object')]

# %%
df.shape
# Out:
# (5000, 7)

# %%
df.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
df.shape
# Out:
# (5000, 7)

# %%
df.dtypes
# Out:
# Avg. Area Income                float64
# Avg. Area House Age             float64
# Avg. Area Number of Rooms       float64
# Avg. Area Number of Bedrooms    float64
# Area Population                 float64
# Price                           float64
# Address                          object
# dtype: object

# %%
df.isna().sum()
# Out:
# Avg. Area Income                0
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Area Population                 0
# Price                           0
# Address                         0
# dtype: int64

# %% [markdown]
# ## Data Visualization :

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
sns.histplot(df)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.distplot(df['Avg. Area Income'])
# Out:
# <Axes: xlabel='Avg. Area Income', ylabel='Density'>

# %%
sns.countplot(df)
# Out:
# <Axes: ylabel='count'>

# %%
sns.pairplot(df)

# %% [markdown]
# ## Compairing Numerical Feature with Categorical Features :

# %%
df.select_dtypes(include = 'object').head()
# Out:
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2  9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3                          USS Barnett\nFPO AP 44820
# 4                         USNS Raymond\nFPO AE 09386

# %%
df.select_dtypes(exclude = 'object').head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05

# %% [markdown]
# ## Using groupby :

# %%
df.groupby('Price').first().head()
# Out:
#                Avg. Area Income  Avg. Area House Age  \
# Price
# 15938.657923       47320.657205             3.558054
# 31140.517620       37971.207566             4.291224
# 88591.770160       60167.672607             4.590613
# 143027.364452      35963.330809             3.438547
# 151527.082627      48735.924512             5.543730
#
#                Avg. Area Number of Rooms  Avg. Area Number of Bedrooms  \
# Price
# 15938.657923                    7.006987                          3.16
# 31140.517620                    5.807510                          3.24
# 88591.770160                    3.950973                          4.06
# 143027.364452                   8.264122                          3.28
# 151527.082627                   6.091906                          2.43
#
#                Area Population  \
# Price
# 15938.657923      15776.618595
# 31140.517620      33267.767728
# 88591.770160      16811.303292
# 143027.364452     24435.777302
# ...

# %% [markdown]
# ## Compairing two features :

# %%
pd.crosstab(df['Avg. Area Number of Rooms'],df['Avg. Area House Age']).head()
# Out:
# Avg. Area House Age        2.644304  2.683043  2.797215  2.797619  2.922736  \
# Avg. Area Number of Rooms
# 3.236194                          0         0         0         0         0
# 3.950225                          0         0         0         0         0
# 3.950973                          0         0         0         0         0
# 3.969632                          0         0         0         0         0
# 4.027931                          0         0         0         0         0
#
# Avg. Area House Age        3.004717  3.055370  3.105751  3.118802  3.144894  \
# Avg. Area Number of Rooms
# 3.236194                          0         0         0         0         0
# 3.950225                          0         0         0         0         0
# 3.950973                          0         0         0         0         0
# 3.969632                          0         0         0         0         0
# 4.027931                          0         0         0         0         0
# ...

# %% [markdown]
# ## Handling Outliers :

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
sns.boxplot(df['Avg. Area Income'])
# Out:
# <Axes: >

# %%
q1 = df['Avg. Area Income'].quantile(0.25)
q3 = df['Avg. Area Income'].quantile(0.75)
median = df['Avg. Area Income'].median()
IQR = q3 - q1
upper_tail = q3 + 1.5 * IQR
lower_tail = q3 - 1.5 * IQR
print('First Quantile : ',q1)
print('Third Quantile : ',q3)
print('IQR :-->',IQR)
print('Upper_tail :-->',upper_tail)
print('Lower tail:',lower_tail)
# Out:
# First Quantile :  61480.562388460974
# Third Quantile :  75783.33866615265
# IQR :--> 14302.776277691672
# Upper_tail :--> 97237.50308269015
# Lower tail: 54329.17424961514

# %%
df['Avg. Area Income'].loc[df['Avg. Area Income']>upper_tail]
# Out:
# 558      99629.013581
# 693     107701.748378
# 962     101928.858060
# 1096     97548.310413
# 1734    104702.724257
# 1891    101144.323930
# 2300     98468.253641
# 2719    101599.670580
# 3483     97881.587279
# 3541    102881.120902
# 3798     97669.064491
# 4087    100741.298585
# 4400     99317.823145
# Name: Avg. Area Income, dtype: float64

# %%
df['Avg. Area Income'].loc[df['Avg. Area Income']>upper_tail]=upper_tail

# %%
df['Avg. Area Income'].loc[df['Avg. Area Income']>upper_tail]
# Out:
# Series([], Name: Avg. Area Income, dtype: float64)

# %%
df['Avg. Area Income'].loc[df['Avg. Area Income']<lower_tail]
# Out:
# 11      50593.695497
# 12      39033.809237
# 33      50218.708463
# 38      53128.185449
# 39      17796.631190
# 42      46147.053056
# 51      49408.198340
# 90      48904.983269
# 107     52202.853720
# 114     51217.181160
# 128     44806.005164
# 144     47681.361733
# 160     52575.815175
# 173     42816.305886
# 183     48531.364229
# 188     52446.266856
# 191     53306.922137
# 193     51296.488630
# 208     51273.508853
# 214     40503.541332
# 223     54299.968820
# 226     44731.109800
# 250     51949.295703
# 253     53287.992072
# 262     53112.278061
# 263     40366.616291
# 299     52188.118727
# 326     51976.023933
# 331     52399.648220
# 344     53546.872140
# 367     54273.914882
# 392     50887.440074
# 411     36100.444227
# 421     52934.435793
# 425     51718.354612
# 432     51992.743291
# 437     44688.563816
# 444     47065.053303
# 485     50846.008064
# 507     53825.013077
# 529     50189.140796
# 543     51044.291697
# 557     51110.934106
# ...

# %%
df['Avg. Area Income'].loc[df['Avg. Area Income']<lower_tail]=lower_tail

# %%
df['Avg. Area Income'].loc[df['Avg. Area Income']<lower_tail]
# Out:
# Series([], Name: Avg. Area Income, dtype: float64)

# %%
sns.boxplot(df['Avg. Area Income'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Avg. Area House Age'])
# Out:
# <Axes: >

# %%
q1 = df['Avg. Area House Age'].quantile(0.25)
q3 = df['Avg. Area House Age'].quantile(0.75)
median = df['Avg. Area House Age'].median()
IQR = q3 - q1
upper_tail = q3 + 1.5 * IQR
lower_tail = q3 - 1.5 * IQR
print('First Quantile : ',q1)
print('Third Quantile : ',q3)
print('IQR :-->',IQR)
print('Upper_tail :-->',upper_tail)
print('Lower tail:',lower_tail)
# Out:
# First Quantile :  5.315831641835594
# Third Quantile :  6.645422179635464
# IQR :--> 1.32959053779987
# Upper_tail :--> 8.639807986335269
# Lower tail: 4.651036372935659

# %%
df['Avg. Area House Age'].loc[df['Avg. Area House Age']>upper_tail]
# Out:
# 3698    8.641821
# Name: Avg. Area House Age, dtype: float64

# %%
df['Avg. Area House Age'].loc[df['Avg. Area House Age']>upper_tail]=upper_tail

# %%
df['Avg. Area House Age'].loc[df['Avg. Area House Age']>upper_tail]
# Out:
# Series([], Name: Avg. Area House Age, dtype: float64)

# %%
df['Avg. Area House Age'].loc[df['Avg. Area House Age']<lower_tail]
# Out:
# Series([], Name: Avg. Area House Age, dtype: float64)

# %%
df['Avg. Area House Age'].loc[df['Avg. Area House Age']<lower_tail]=lower_tail

# %%
df['Avg. Area House Age'].loc[df['Avg. Area House Age']<lower_tail]
# Out:
# Series([], Name: Avg. Area House Age, dtype: float64)

# %%
sns.boxplot(df['Avg. Area House Age'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Avg. Area Number of Rooms'])
# Out:
# <Axes: >

# %%
df['Avg. Area Number of Rooms'].loc[df['Avg. Area Number of Rooms']>upper_tail]
# Out:
# 34       9.289854
# 114      8.776160
# 126      9.468766
# 136      8.920333
# 166      8.877240
# 180      9.180401
# 220      9.054710
# 226      8.942797
# 227      9.524974
# 238      9.710217
# 266      8.933120
# 292      9.086808
# 296      8.960743
# 303      8.965705
# 316      9.024503
# 331      8.971112
# 334      9.442325
# 406      8.971412
# 433      9.069530
# 441      9.152073
# 446      8.837002
# 450      8.791775
# 452      8.672979
# 465      9.708803
# 472      8.869467
# 505      9.462720
# 515      9.166350
# 525      8.675575
# 536      8.756045
# 568      9.410157
# 581      8.848999
# 672      8.764794
# 697      8.707035
# 750      8.720523
# 794      9.570048
# 800      8.699544
# 813      8.692723
# 818      8.791164
# 901      9.179994
# 928      9.098980
# 949      8.749001
# 950      8.678774
# 962      9.039382
# 975      8.657343
# 981      9.699773
# 987      8.810884
# 989      8.931185
# 998      8.765481
# 1014     9.079235
# 1023     8.723668
# ...

# %%
df['Avg. Area Number of Rooms'].loc[df['Avg. Area Number of Rooms']>upper_tail]=upper_tail

# %%
df['Avg. Area Number of Rooms'].loc[df['Avg. Area Number of Rooms']>upper_tail]
# Out:
# Series([], Name: Avg. Area Number of Rooms, dtype: float64)

# %%
df['Avg. Area Number of Rooms'].loc[df['Avg. Area Number of Rooms']<lower_tail]
# Out:
# 28      4.242191
# 63      4.580840
# 88      4.500165
# 107     4.414381
# 169     4.652718
# 315     4.651974
# 496     3.236194
# 510     4.458941
# 675     4.432448
# 859     4.626558
# 1107    4.377966
# 1110    4.049321
# 1237    4.630230
# 1283    4.620870
# 1409    4.406836
# 1423    4.129733
# 1675    4.430372
# 1728    4.635161
# 1757    3.969632
# 1799    3.950973
# 1875    4.652449
# 1971    4.474536
# 1990    4.393192
# 1996    4.583646
# 2103    4.632911
# 2120    4.290699
# 2237    4.407346
# 2273    4.460530
# 2659    4.583870
# 2693    4.525421
# 2710    4.415753
# 2771    3.950225
# 2896    4.419215
# 2956    4.513354
# 2963    4.198677
# 2996    4.541467
# 3111    4.316259
# 3233    4.498699
# 3392    4.626054
# 3482    4.621620
# 3600    4.087718
# 3758    4.365671
# 3787    4.608843
# 3803    4.147431
# 3838    4.334884
# 3862    4.490072
# 3902    4.298221
# 3922    4.027931
# 4042    4.472098
# 4163    4.384629
# 4309    4.499120
# 4318    4.125278
# ...

# %%
df['Avg. Area Number of Rooms'].loc[df['Avg. Area Number of Rooms']<lower_tail]=lower_tail

# %%
df['Avg. Area Number of Rooms'].loc[df['Avg. Area Number of Rooms']<lower_tail]
# Out:
# Series([], Name: Avg. Area Number of Rooms, dtype: float64)

# %%
sns.boxplot(df['Avg. Area Number of Rooms'])
# Out:
# <Axes: >

# %%
q1 = df['Price'].quantile(0.25)
q3 = df['Price'].quantile(0.75)
median = df['Price'].median()
IQR = q3 - q1
upper_tail = q3 + 1.5 * IQR
lower_tail = q3 - 1.5 * IQR
print('First Quantile : ',q1)
print('Third Quantile : ',q3)
print('IQR :-->',IQR)
print('Upper_tail :-->',upper_tail)
print('Lower tail:',lower_tail)
# Out:
# First Quantile :  8.643596674836909
# Third Quantile :  8.643596674836909
# IQR :--> 0.0
# Upper_tail :--> 8.643596674836909
# Lower tail: 8.643596674836909

# %%
df['Price'].loc[df['Price']>upper_tail]
# Out:
# Series([], Name: Price, dtype: float64)

# %%
df['Price'].loc[df['Price']>upper_tail]=upper_tail

# %%
df['Price'].loc[df['Price']>upper_tail]
# Out:
# Series([], Name: Price, dtype: float64)

# %%
df['Price'].loc[df['Price']<lower_tail]
# Out:
# Series([], Name: Price, dtype: float64)

# %%
df['Price'].loc[df['Price']<lower_tail]=lower_tail

# %%
df['Price'].loc[df['Price']<lower_tail]
# Out:
# Series([], Name: Price, dtype: float64)

# %%
sns.boxplot(df['Price'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Area Population'])
# Out:
# <Axes: >

# %%
df['Area Population'].loc[df['Area Population']>upper_tail]
# Out:
# 0       23086.800503
# 1       40173.072174
# 2       36882.159400
# 3       34310.242831
# 4       26354.109472
# 5       26748.428425
# 6       60828.249085
# 7       36516.358972
# 8       29387.396003
# 9       40149.965749
# 10      47224.359840
# 11      34343.991886
# 12      39220.361467
# 13      32326.123139
# 14      35521.294033
# 15      23929.524053
# 16      39717.813576
# 17      24595.901498
# 18      35719.653052
# 19      44922.106702
# 20      47560.775336
# 21      45574.741662
# 22      40358.960106
# 23      28140.967088
# 24      27809.986544
# 25      40694.869513
# 26      38853.918066
# 27      27784.742280
# 28      33970.164990
# 29      37520.657732
# 30      33754.737805
# 31      39355.625729
# 32      30122.473484
# 33      16810.783311
# 34      22355.235407
# 35      39395.151182
# 36      27637.656548
# 37      22836.607569
# 38      32947.711955
# 39      47162.183643
# 40      39705.464959
# 41      32778.195342
# 42      27161.128608
# ...

# %%
df['Area Population'].loc[df['Area Population']>upper_tail]=upper_tail

# %%
df['Area Population'].loc[df['Area Population']>upper_tail]
# Out:
# Series([], Name: Area Population, dtype: float64)

# %%
df['Area Population'].loc[df['Area Population']<lower_tail]
# Out:
# Series([], Name: Area Population, dtype: float64)

# %%
df['Area Population'].loc[df['Area Population']<lower_tail]=lower_tail

# %%
df['Area Population'].loc[df['Area Population']<lower_tail]
# Out:
# Series([], Name: Area Population, dtype: float64)

# %%
sns.boxplot(df['Area Population'])
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %% [markdown]
# ## Feature Selection :

# %% [markdown]
# ## Linearity :

# %%
import matplotlib
import seaborn
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.dtypes
# Out:
# Avg. Area Income                float64
# Avg. Area House Age             float64
# Avg. Area Number of Rooms       float64
# Avg. Area Number of Bedrooms    float64
# Area Population                 float64
# Price                           float64
# Address                          object
# dtype: object

# %%
df.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population     Price  \
# 0                          4.09         8.643597  8.643597
# 1                          3.09         8.643597  8.643597
# 2                          5.13         8.643597  8.643597
# 3                          3.26         8.643597  8.643597
# 4                          4.23         8.643597  8.643597
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
# Convert all numeric columns to numeric data type
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns
df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')

# Check for remaining non-numeric values
non_numeric_columns = df.select_dtypes(exclude=['float64', 'int64']).columns
if len(non_numeric_columns) > 0:
    print("Non-numeric columns:", non_numeric_columns)
# Out:
# Non-numeric columns: Index(['Address'], dtype='object')

# %%
r = df.corr()
r

# %%
plt.figure(figsize = (3,10))
sns.heatmap(r,annot = True)
# Out:
# <Axes: >

# %% [markdown]
# ## Multicollinearity :

# %%
df1 = df.drop('Price',axis = 1)
df1.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population  \
# 0                          4.09         8.643597
# 1                          3.09         8.643597
# 2                          5.13         8.643597
# 3                          3.26         8.643597
# 4                          4.23         8.643597
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2  9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif_list = []
for i in range(df.shape[1]) :
 vif = variance_inflation_factor(df,i)
 vif_list.append(vif)
print(vif_list)

# %% [markdown]
# ## Model Building :

# %%
from sklearn.linear_model import LinearRegression

# %%
x = df.drop('Price',axis = 1)
y = df['Price']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size =0.2 , random_state=42)

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)

# %%
y_pred = model.predict(x_test)

# %%
y_pred_train = model.predict(x_train)

# %%
df2 = df.to_csv('second.csv')
df2
