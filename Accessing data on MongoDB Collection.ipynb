# %%
import pandas as pd

import warnings

warnings.filterwarnings('ignore')

# %%
df1 = pd.read_csv('first.csv')
df1.shape
# Out:
# (303, 15)

# %%
df2 = pd.read_csv('second.csv')
df2.shape
# Out:
# (5000, 8)

# %%
df3 = pd.read_csv('third.csv')
df3.shape
# Out:
# (30, 3)

# %%
DF = pd.concat([df1,df2,df3])
DF.shape
# Out:
# (5333, 24)

# %%
DF_1 = DF.to_csv('Merge.csv')
DF_1

# %%
DF_2 = pd.read_csv('Merge.csv')
DF_2.shape
# Out:
# (5333, 25)

# %%
pip install PyMongo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymongo

# %%
# creating connection

server = pymongo.MongoClient('mongodb://localhost:27017')
server
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
#  creating DataBase

db = server['Spectacle']
db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'Spectacle')

# %%
# creating Collection

col = db['Frenetic']
col
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'Spectacle'), 'Frenetic')

# %%
data = DF_2.to_dict(orient = 'records')
data
# Out:
# [{'Unnamed: 0.1': 0,
#   'Unnamed: 0': 0,
#   'age': 63.0,
#   'sex': 1.0,
#   'cp': 3.0,
#   'trestbps': 145.0,
#   'chol': 233.0,
#   'fbs': 0.0,
#   'restecg': 0.0,
#   'thalach': 150.0,
#   'exang': 0.0,
#   'oldpeak': 2.3,
#   'slope': 0.0,
#   'ca': 0.0,
#   'thal': 1.5,
#   'target': 1.0,
#   'Avg. Area Income': nan,
#   'Avg. Area House Age': nan,
#   'Avg. Area Number of Rooms': nan,
#   'Avg. Area Number of Bedrooms': nan,
#   'Area Population': nan,
#   'Price': nan,
#   'Address': nan,
#   'YearsExperience': nan,
#   'Salary': nan},
#  {'Unnamed: 0.1': 1,
#   'Unnamed: 0': 1,
#   'age': 37.0,
#   'sex': 1.0,
#   'cp': 2.0,
#   'trestbps': 130.0,
#   'chol': 250.0,
#   'fbs': 0.0,
#   'restecg': 1.0,
#   'thalach': 187.0,
#   'exang': 0.0,
#   'oldpeak': 3.5,
#   'slope': 0.0,
#   'ca': 0.0,
#   'thal': 2.0,
#   'target': 1.0,
#   'Avg. Area Income': nan,
#   'Avg. Area House Age': nan,
#   'Avg. Area Number of Rooms': nan,
#   'Avg. Area Number of Bedrooms': nan,
# ...

# %%
db.Frenetic.insert_many(data)
# Out:
# InsertManyResult([ObjectId('660e9f661c89e7c7e745ffc6'), ObjectId('660e9f661c89e7c7e745ffc7'), ObjectId('660e9f661c89e7c7e745ffc8'), ObjectId('660e9f661c89e7c7e745ffc9'), ObjectId('660e9f661c89e7c7e745ffca'), ObjectId('660e9f661c89e7c7e745ffcb'), ObjectId('660e9f661c89e7c7e745ffcc'), ObjectId('660e9f661c89e7c7e745ffcd'), ObjectId('660e9f661c89e7c7e745ffce'), ObjectId('660e9f661c89e7c7e745ffcf'), ObjectId('660e9f661c89e7c7e745ffd0'), ObjectId('660e9f661c89e7c7e745ffd1'), ObjectId('660e9f661c89e7c7e745ffd2'), ObjectId('660e9f661c89e7c7e745ffd3'), ObjectId('660e9f661c89e7c7e745ffd4'), ObjectId('660e9f661c89e7c7e745ffd5'), ObjectId('660e9f661c89e7c7e745ffd6'), ObjectId('660e9f661c89e7c7e745ffd7'), ObjectId('660e9f661c89e7c7e745ffd8'), ObjectId('660e9f661c89e7c7e745ffd9'), ObjectId('660e9f661c89e7c7e745ffda'), ObjectId('660e9f661c89e7c7e745ffdb'), ObjectId('660e9f661c89e7c7e745ffdc'), ObjectId('660e9f661c89e7c7e745ffdd'), ObjectId('660e9f661c89e7c7e745ffde'), ObjectId('660e9f661c89e7c7e745
# ...

# %% [markdown]
# ![image.png](attachment:fbb0fa86-d619-414c-8131-37482052279b.png)
